# %%
import pandas as pd
import numpy as np

# %%
df_heart = pd.read_csv('heart.csv', delimiter=',')

# %%
df_heart.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df_heart.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df_heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df_heart.shape
# Out:
# (303, 14)

# %%
df_heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
##DATA CLEANING
df_heart.duplicated().sum()
# Out:
# np.int64(1)

# %%
df_heart = df_heart.drop_duplicates()

# %%
df_heart
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
##DATA INTEGRATION
df1 = df_heart[['age','cp','trtbps','chol','fbs','slp']]
df2 = df_heart[['age' , 'caa' ,'thall' ,'thalachh' , 'output']]

# %%
df1
# Out:
#      age  cp  trtbps  chol  fbs  slp
# 0     63   3     145   233    1    0
# 1     37   2     130   250    0    0
# 2     41   1     130   204    0    2
# 3     56   1     120   236    0    2
# 4     57   0     120   354    0    2
# ..   ...  ..     ...   ...  ...  ...
# 298   57   0     140   241    0    1
# 299   45   3     110   264    0    1
# 300   68   0     144   193    1    1
# 301   57   0     130   131    0    1
# 302   57   1     130   236    0    1
#
# [302 rows x 6 columns]

# %%
df2
# Out:
#      age  caa  thall  thalachh  output
# 0     63    0      1       150       1
# 1     37    0      2       187       1
# 2     41    0      2       172       1
# 3     56    0      2       178       1
# 4     57    0      2       163       1
# ..   ...  ...    ...       ...     ...
# 298   57    0      3       123       0
# 299   45    0      3       132       0
# 300   68    2      3       141       0
# 301   57    1      3       115       0
# 302   57    1      2       174       0
#
# [302 rows x 5 columns]

# %%
merged_data = pd.merge(df1,df2,on='age' , how='inner')

# %%
merged_data
# Out:
#       age  cp  trtbps  chol  fbs  slp  caa  thall  thalachh  output
# 0      63   3     145   233    1    0    0      1       150       1
# 1      63   3     145   233    1    0    0      2       172       1
# 2      63   3     145   233    1    0    2      2       179       1
# 3      63   3     145   233    1    0    1      3       147       0
# 4      63   3     145   233    1    0    3      3       132       0
# ...   ...  ..     ...   ...  ...  ...  ...    ...       ...     ...
# 3057   57   1     130   236    0    1    1      2       164       0
# 3058   57   1     130   236    0    1    1      3       143       0
# 3059   57   1     130   236    0    1    0      3       123       0
# 3060   57   1     130   236    0    1    1      3       115       0
# 3061   57   1     130   236    0    1    1      2       174       0
#
# [3062 rows x 10 columns]

# %%
merged_data = merged_data.drop_duplicates(['age'])

# %%
merged_data
# Out:
#       age  cp  trtbps  chol  fbs  slp  caa  thall  thalachh  output
# 0      63   3     145   233    1    0    0      1       150       1
# 9      37   2     130   250    0    0    0      2       187       1
# 11     41   1     130   204    0    2    0      2       172       1
# 21     56   1     120   236    0    2    0      2       178       1
# 32     57   0     120   354    0    2    0      2       163       1
# 77     44   1     120   263    0    2    0      3       173       1
# 88     52   2     172   199    1    2    0      3       162       1
# 118    54   0     140   239    0    2    0      2       160       1
# 134    48   2     130   275    0    2    0      2       139       1
# 141    49   1     130   266    0    2    0      2       171       1
# 146    64   3     110   211    0    1    0      2       144       1
# 156    58   3     150   283    1    2    0      2       162       1
# 175    50   2     120   219    0    1    0      2       158       1
# ...

# %%
merged_data.shape
# Out:
# (41, 10)

# %%
##ERROR CORRECTION
def remove_outlier(column):
    column=column.copy()
    Q1=column.quantile(0.25)
    Q3=column.quantile(0.75)
    IQR=Q3-Q1
    threshold=1.5*IQR
    outlier_mask = (column < Q1-threshold) | (column > Q3+threshold)
    return column[~outlier_mask]

# %%
col_name = ['age' ,'cp', 'trtbps' , 'chol' , 'fbs' , 'slp' , 'caa' , 'thall' , 'thalachh']

# %%
for col in col_name: 
    merged_data.loc[: , col] = remove_outlier(merged_data[col])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_45396\1137931816.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[145. 130. 130. 120. 120. 120.  nan 140. 130. 130. 110. 150. 120. 150.
#  150. 140. 135. 140. 150. 140. 160. 110. 140. 130. 142. 104. 140. 138.
#  130. 118. 138. 130. 135. 102. 115. 118. 120. 140. 156. 138. 125.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   merged_data.loc[: , col] = remove_outlier(merged_data[col])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_45396\1137931816.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[233. 250. 204. 236. 354. 263. 199. 239. 275. 266. 211. 283. 219. 226.
#  247. 239. 234. 226. 243. 199. 302. 175.  nan 197. 177. 208. 321. 257.
# ...

# %%
merged_data.reset_index(drop=True , inplace=True)

# %%
new_data  = merged_data.fillna(merged_data.mean(numeric_only=True))

# %%
new_data
# Out:
#     age  cp   trtbps        chol  fbs  slp  caa  thall    thalachh  output
# 0    63   3  145.000  233.000000  0.0    0  0.0    2.0  150.000000       1
# 1    37   2  130.000  250.000000  0.0    0  0.0    2.0  187.000000       1
# 2    41   1  130.000  204.000000  0.0    2  0.0    2.0  172.000000       1
# 3    56   1  120.000  236.000000  0.0    2  0.0    2.0  178.000000       1
# 4    57   0  120.000  354.000000  0.0    2  0.0    2.0  163.000000       1
# 5    44   1  120.000  263.000000  0.0    2  0.0    2.0  173.000000       1
# 6    52   2  131.975  199.000000  0.0    2  0.0    2.0  162.000000       1
# 7    54   0  140.000  239.000000  0.0    2  0.0    2.0  160.000000       1
# 8    48   2  130.000  275.000000  0.0    2  0.0    2.0  139.000000       1
# 9    49   1  130.000  266.000000  0.0    2  0.0    2.0  171.000000       1
# 10   64   3  110.000  211.000000  0.0    1  0.0    2.0  144.000000       1
# ...

# %%
##DATA SPLIT
from sklearn.model_selection import train_test_split
##index in new data is beyond the shape of the df_heart it will throw error if passed directly to x

# %%
x = df_heart.drop(columns='output')
y = df_heart['output']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape , x_test.shape , y_train.shape , y_test.shape
# Out:
# ((241, 13), (61, 13), (241,), (61,))

# %%
##DATA TRANSFORMATION
##1.LOGISTIC REGRESSION
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
##DATA MODELING 
##1.LOGISTIC REGRESSION
from sklearn.linear_model import LogisticRegression
logistic_regression = LogisticRegression()
logistic_regression.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
prediction = logistic_regression.predict(x_test_scaled)

# %%
from sklearn.metrics import accuracy_score , confusion_matrix

accuracy = accuracy_score(y_test , prediction)
cm = confusion_matrix(y_test , prediction)

print('The accuracy is : ' , accuracy)
print('The confusion matrix is : ' )
print(cm)
# Out:
# The accuracy is :  0.819672131147541
# The confusion matrix is :
# [[24  5]
#  [ 6 26]]

# %%
##2. DECISION TREE
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier(random_state=42)

# %%
decision_tree.fit(x_train_scaled , y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
prediction_tree = decision_tree.predict(x_test_scaled)

# %%
accuracy_tree = accuracy_score(y_test,prediction_tree)
cm_tree = confusion_matrix(y_test,prediction_tree)

# %%
print('The accuracy is : ' , accuracy_tree)
print('The confusion matrix is : ' )
print(cm_tree)
# Out:
# The accuracy is :  0.7704918032786885
# The confusion matrix is :
# [[25  4]
#  [10 22]]

# %%
df_heart['output'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df['output'].value_counts()
#
# NameError: name 'df' is not defined
